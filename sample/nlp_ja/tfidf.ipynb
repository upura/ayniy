# %%
import pandas as pd
from ayniy.utils import init_notebook
from ayniy.preprocessing.nlp import create_parsed_document
from ayniy.preprocessing.nlp import get_tfidf_svd_nmf_bm25, get_count_svd_nmf_bm25
# Out:
# /opt/conda/lib/python3.6/site-packages/smart_open/ssh.py:34: UserWarning: paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress
#   warnings.warn('paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress')

# %%
init_notebook()
# Out:
# <style>.container { width:100% !important; }</style>

# %%
headline = [
    'Kaggleにおける「特徴量エンジニアリング」の位置づけ　〜『機械学習のための特徴量エンジニアリング』に寄せて',
    '【Kaggleのフォルダ構成や管理方法】タイタニック用のGitHubリポジトリを公開しました',
    'KaggleのWinner solutionにもなった「K近傍を用いた特徴量抽出」のPython実装',
    'Pythonを用いたKaggle入門書を2020年3月に講談社から出版します',
    '【書評】『Kaggleで勝つデータ分析の技術』（技術評論社）',
    '「初手LightGBM」をする7つの理由「初手LightGBM」をする7つの理由',
    'scikit-learn-contribのMetric Learningを試す',
    '遺伝的プログラミングによる特徴量生成でLightGBMの精度向上【kaggle Advent Calendar 11日目】',
    '2018年のKaggleの"leak"を眺めてみる',
    'Rを用いて般若心経を感情分析してみた'
]

bookmark = [
    213,
    178,
    143,
    106,
    75,
    57,
    38,
    32,
    29,
    26
]

train = pd.DataFrame({
    'headline': headline,
    'bookmark': bookmark
})

train.head()
# Out:
#                                             headline  bookmark
# 0  Kaggleにおける「特徴量エンジニアリング」の位置づけ　〜『機械学習のための特徴量エンジニ...       213
# 1     【Kaggleのフォルダ構成や管理方法】タイタニック用のGitHubリポジトリを公開しました       178
# 2  KaggleのWinner solutionにもなった「K近傍を用いた特徴量抽出」のPyth...       143
# 3             Pythonを用いたKaggle入門書を2020年3月に講談社から出版します       106
# 4                     【書評】『Kaggleで勝つデータ分析の技術』（技術評論社）        75

# %%
train['parsed_headline'] = create_parsed_document(train['headline'])
train['join_parsed_headline'] = [' '.join(text) for text in train['parsed_headline']]

train, test = get_tfidf_svd_nmf_bm25(train, train, 'join_parsed_headline')
train, test = get_count_svd_nmf_bm25(train, train, 'join_parsed_headline')

train.head()
# Out:
# /working/ayniy/preprocessing/nlp.py:757: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# /working/ayniy/preprocessing/nlp.py:757: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
#                                             headline  bookmark  \
# 0  Kaggleにおける「特徴量エンジニアリング」の位置づけ　〜『機械学習のための特徴量エンジニ...       213
# 1     【Kaggleのフォルダ構成や管理方法】タイタニック用のGitHubリポジトリを公開しました       178
# 2  KaggleのWinner solutionにもなった「K近傍を用いた特徴量抽出」のPyth...       143
# 3             Pythonを用いたKaggle入門書を2020年3月に講談社から出版します       106
# 4                     【書評】『Kaggleで勝つデータ分析の技術』（技術評論社）        75
#
# ...
